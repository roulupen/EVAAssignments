# %% [markdown]
# <a href="https://colab.research.google.com/github/roulupen/EVAAssignments/blob/master/Assignment-9/Assignment9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
import cv2
import sys
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Loading data from CIFAR10 dataset

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))

# %% [markdown]
# ### Display pictures of different classes

# %%
class_names = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %% [markdown]
# ### Drawing model accuracy(Train vs Validation) and model loss(Train vs Valisation) from model execution history

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %% [markdown]
# ### Calculating accuracy of a model from the input dataset and model

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %% [markdown]
# ### Pixel normalization and using hot encoding converting the output labels into hot encoding values for train and test dataset

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %% [markdown]
# ## Defining a sequential model without cut out and applying Grad-Cam to layer before final Convolution layer and drawing the heat map

# %%
# Define the model
new_model = Sequential()
new_model.add(Convolution2D(64, 3, 3, border_mode='same', input_shape=(32, 32, 3)))
new_model.add(Activation('relu'))#32
new_model.add(BatchNormalization())
new_model.add(Dropout(0.3))

new_model.add(Convolution2D(128, 3, 3))
new_model.add(Activation('relu'))#30
new_model.add(BatchNormalization())
new_model.add(Dropout(0.3))

new_model.add(MaxPooling2D(pool_size=(2, 2)))#15
new_model.add(Convolution2D(64, 1, activation='relu'))

new_model.add(Convolution2D(128, 3, 3, border_mode='same'))
new_model.add(Activation('relu'))#15
new_model.add(BatchNormalization())
new_model.add(Dropout(0.3))

new_model.add(Convolution2D(256, 3, 3))
new_model.add(Activation('relu'))#13

new_model.add(MaxPooling2D(pool_size=(2, 2)))#6
new_model.add(Convolution2D(128, 1, activation='relu'))

new_model.add(Convolution2D(256, 3, 3, border_mode='same'))
new_model.add(Activation('relu'))#6
new_model.add(BatchNormalization())
new_model.add(Dropout(0.3))

new_model.add(Convolution2D(512, 3, 3))
new_model.add(Activation('relu'))#4x4
new_model.add(BatchNormalization())
new_model.add(Dropout(0.3))

new_model.add(Convolution2D(256, 1, 1, activation='relu'))
new_model.add(BatchNormalization())
new_model.add(Dropout(0.3))

new_model.add(Convolution2D(num_classes, 4, 4))#1
new_model.add(Flatten())
new_model.add(Activation('softmax'))

# Compile the model
new_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3))`
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same")`
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:31: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:36: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), activation="relu")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (4, 4))`

# %%
new_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 32, 32, 64)        1792
# _________________________________________________________________
# activation_8 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 30, 30, 128)       73856
# _________________________________________________________________
# activation_9 (Activation)    (None, 30, 30, 128)       0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 30, 30, 128)       512
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 30, 30, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 128)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 15, 15, 64)        8256
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 15, 15, 128)       73856
# _________________________________________________________________
# activation_10 (Activation)   (None, 15, 15, 128)       0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 15, 15, 128)       512
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 15, 15, 128)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 13, 13, 256)       295168
# _________________________________________________________________
# activation_11 (Activation)   (None, 13, 13, 256)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 6, 6, 128)         32896
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 6, 6, 256)         295168
# _________________________________________________________________
# activation_12 (Activation)   (None, 6, 6, 256)         0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 6, 6, 256)         1024
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 6, 6, 256)         0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 4, 4, 512)         1180160
# _________________________________________________________________
# activation_13 (Activation)   (None, 4, 4, 512)         0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 4, 4, 256)         131328
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 1, 1, 10)          40970
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_14 (Activation)   (None, 10)                0
# =================================================================
# Total params: 2,138,826
# Trainable params: 2,136,138
# Non-trainable params: 2,688
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.callbacks import EarlyStopping

datagen = ImageDataGenerator(zoom_range=0.0, horizontal_flip=False)
checkpointer = ModelCheckpoint(filepath='assignment9.h5', verbose = 1, save_best_only=True, monitor='val_acc', mode='max')
lr_reducer = ReduceLROnPlateau(monitor='val_acc',factor=0.8, cooldown=0, patience=5, min_lr=0.5e-9,verbose = 1)

# train the model
start = time.time()

# Train the model
new_model_info = new_model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 256), samples_per_epoch = train_features.shape[0], nb_epoch = 50,
                                         validation_data = (test_features, test_labels), verbose=1, callbacks=[checkpointer, lr_reducer])
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))

# plot model history
plot_model_history(new_model_info)

# compute test accuracy
# Load the weights with the best validation accuracy:
new_model.load_weights('assignment9.h5')
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, new_model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=195, epochs=50)`
# Epoch 1/50
# 195/195 [==============================] - 49s 249ms/step - loss: 1.7452 - acc: 0.4223 - val_loss: 1.6207 - val_acc: 0.4455
#
# Epoch 00001: val_acc improved from -inf to 0.44550, saving model to assignment9.h5
# Epoch 2/50
# 195/195 [==============================] - 46s 236ms/step - loss: 1.1621 - acc: 0.5999 - val_loss: 1.1694 - val_acc: 0.5882
#
# Epoch 00002: val_acc improved from 0.44550 to 0.58820, saving model to assignment9.h5
# Epoch 3/50
# 195/195 [==============================] - 46s 236ms/step - loss: 1.0077 - acc: 0.6632 - val_loss: 3.0324 - val_acc: 0.2747
#
# Epoch 00003: val_acc did not improve from 0.58820
# Epoch 4/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.9476 - acc: 0.6846 - val_loss: 1.0651 - val_acc: 0.6376
#
# Epoch 00004: val_acc improved from 0.58820 to 0.63760, saving model to assignment9.h5
# Epoch 5/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.7098 - acc: 0.7507 - val_loss: 0.8109 - val_acc: 0.7079
#
# Epoch 00005: val_acc improved from 0.63760 to 0.70790, saving model to assignment9.h5
# Epoch 6/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.6228 - acc: 0.7826 - val_loss: 0.8629 - val_acc: 0.6972
#
# Epoch 00006: val_acc did not improve from 0.70790
# Epoch 7/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.5762 - acc: 0.7980 - val_loss: 0.7977 - val_acc: 0.7303
#
# Epoch 00007: val_acc improved from 0.70790 to 0.73030, saving model to assignment9.h5
# Epoch 8/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.5097 - acc: 0.8224 - val_loss: 0.8570 - val_acc: 0.7151
#
# Epoch 00008: val_acc did not improve from 0.73030
# Epoch 9/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.4732 - acc: 0.8350 - val_loss: 0.6932 - val_acc: 0.7603
#
# Epoch 00009: val_acc improved from 0.73030 to 0.76030, saving model to assignment9.h5
# Epoch 10/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.4369 - acc: 0.8471 - val_loss: 0.8382 - val_acc: 0.7163
#
# Epoch 00010: val_acc did not improve from 0.76030
# Epoch 11/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.4200 - acc: 0.8540 - val_loss: 0.6446 - val_acc: 0.7903
#
# Epoch 00011: val_acc improved from 0.76030 to 0.79030, saving model to assignment9.h5
# Epoch 12/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.3701 - acc: 0.8702 - val_loss: 0.6782 - val_acc: 0.7804
#
# Epoch 00012: val_acc did not improve from 0.79030
# Epoch 13/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.3430 - acc: 0.8784 - val_loss: 0.7064 - val_acc: 0.7705
#
# Epoch 00013: val_acc did not improve from 0.79030
# Epoch 14/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.3146 - acc: 0.8881 - val_loss: 0.7124 - val_acc: 0.7689
#
# Epoch 00014: val_acc did not improve from 0.79030
# Epoch 15/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.2912 - acc: 0.8964 - val_loss: 0.6613 - val_acc: 0.7968
#
# Epoch 00015: val_acc improved from 0.79030 to 0.79680, saving model to assignment9.h5
# Epoch 16/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.2828 - acc: 0.9002 - val_loss: 0.6620 - val_acc: 0.7999
#
# Epoch 00016: val_acc improved from 0.79680 to 0.79990, saving model to assignment9.h5
# Epoch 17/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.2631 - acc: 0.9043 - val_loss: 0.7213 - val_acc: 0.7947
#
# Epoch 00017: val_acc did not improve from 0.79990
# Epoch 18/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.2487 - acc: 0.9116 - val_loss: 0.5950 - val_acc: 0.8179
#
# Epoch 00018: val_acc improved from 0.79990 to 0.81790, saving model to assignment9.h5
# Epoch 19/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.2258 - acc: 0.9204 - val_loss: 0.5916 - val_acc: 0.8217
#
# Epoch 00019: val_acc improved from 0.81790 to 0.82170, saving model to assignment9.h5
# Epoch 20/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.2132 - acc: 0.9246 - val_loss: 0.7252 - val_acc: 0.7979
#
# Epoch 00020: val_acc did not improve from 0.82170
# Epoch 21/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.2341 - acc: 0.9173 - val_loss: 0.6427 - val_acc: 0.8105
#
# Epoch 00021: val_acc did not improve from 0.82170
# Epoch 22/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.2267 - acc: 0.9192 - val_loss: 0.7240 - val_acc: 0.7961
#
# Epoch 00022: val_acc did not improve from 0.82170
# Epoch 23/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.1970 - acc: 0.9298 - val_loss: 0.5770 - val_acc: 0.8369
#
# Epoch 00023: val_acc improved from 0.82170 to 0.83690, saving model to assignment9.h5
# Epoch 24/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.1799 - acc: 0.9365 - val_loss: 0.6998 - val_acc: 0.7952
#
# Epoch 00024: val_acc did not improve from 0.83690
# Epoch 25/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.1692 - acc: 0.9414 - val_loss: 0.6767 - val_acc: 0.8185
#
# Epoch 00025: val_acc did not improve from 0.83690
# Epoch 26/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.1520 - acc: 0.9450 - val_loss: 0.6388 - val_acc: 0.8266
#
# Epoch 00026: val_acc did not improve from 0.83690
# Epoch 27/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.1496 - acc: 0.9457 - val_loss: 0.6586 - val_acc: 0.8196
#
# Epoch 00027: val_acc did not improve from 0.83690
# Epoch 28/50
# 195/195 [==============================] - 46s 234ms/step - loss: 0.1499 - acc: 0.9475 - val_loss: 0.6366 - val_acc: 0.8335
#
# Epoch 00028: val_acc did not improve from 0.83690
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# Epoch 29/50
# 195/195 [==============================] - 46s 234ms/step - loss: 0.1164 - acc: 0.9582 - val_loss: 0.6653 - val_acc: 0.8314
#
# Epoch 00029: val_acc did not improve from 0.83690
# Epoch 30/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.1079 - acc: 0.9618 - val_loss: 0.5982 - val_acc: 0.8447
#
# Epoch 00030: val_acc improved from 0.83690 to 0.84470, saving model to assignment9.h5
# Epoch 31/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.1035 - acc: 0.9632 - val_loss: 0.6745 - val_acc: 0.8371
#
# Epoch 00031: val_acc did not improve from 0.84470
# Epoch 32/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.0960 - acc: 0.9664 - val_loss: 0.7927 - val_acc: 0.8168
#
# Epoch 00032: val_acc did not improve from 0.84470
# Epoch 33/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.0996 - acc: 0.9641 - val_loss: 0.6437 - val_acc: 0.8349
#
# Epoch 00033: val_acc did not improve from 0.84470
# Epoch 34/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.0999 - acc: 0.9637 - val_loss: 0.7827 - val_acc: 0.8104
#
# Epoch 00034: val_acc did not improve from 0.84470
# Epoch 35/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.0976 - acc: 0.9654 - val_loss: 0.7338 - val_acc: 0.8232
#
# Epoch 00035: val_acc did not improve from 0.84470
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# Epoch 36/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.0869 - acc: 0.9692 - val_loss: 0.7687 - val_acc: 0.8258
#
# Epoch 00036: val_acc did not improve from 0.84470
# Epoch 37/50
# 195/195 [==============================] - 46s 234ms/step - loss: 0.0677 - acc: 0.9762 - val_loss: 0.7272 - val_acc: 0.8348
#
# Epoch 00037: val_acc did not improve from 0.84470
# Epoch 38/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.0654 - acc: 0.9764 - val_loss: 0.7081 - val_acc: 0.8387
#
# Epoch 00038: val_acc did not improve from 0.84470
# Epoch 39/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.0665 - acc: 0.9774 - val_loss: 0.6783 - val_acc: 0.8485
#
# Epoch 00039: val_acc improved from 0.84470 to 0.84850, saving model to assignment9.h5
# Epoch 40/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.0651 - acc: 0.9769 - val_loss: 0.7344 - val_acc: 0.8302
#
# Epoch 00040: val_acc did not improve from 0.84850
# Epoch 41/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.0660 - acc: 0.9771 - val_loss: 0.7139 - val_acc: 0.8458
#
# Epoch 00041: val_acc did not improve from 0.84850
# Epoch 42/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.0669 - acc: 0.9761 - val_loss: 0.8030 - val_acc: 0.8250
#
# Epoch 00042: val_acc did not improve from 0.84850
# Epoch 43/50
# 195/195 [==============================] - 46s 234ms/step - loss: 0.0731 - acc: 0.9756 - val_loss: 0.6951 - val_acc: 0.8449
#
# Epoch 00043: val_acc did not improve from 0.84850
# Epoch 44/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.0551 - acc: 0.9804 - val_loss: 0.7156 - val_acc: 0.8428
#
# Epoch 00044: val_acc did not improve from 0.84850
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# Epoch 45/50
# 195/195 [==============================] - 46s 234ms/step - loss: 0.0554 - acc: 0.9805 - val_loss: 0.7190 - val_acc: 0.8479
#
# Epoch 00045: val_acc did not improve from 0.84850
# Epoch 46/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.0444 - acc: 0.9844 - val_loss: 0.7021 - val_acc: 0.8481
#
# Epoch 00046: val_acc did not improve from 0.84850
# Epoch 47/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.0476 - acc: 0.9834 - val_loss: 0.7463 - val_acc: 0.8461
#
# Epoch 00047: val_acc did not improve from 0.84850
# Epoch 48/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.0449 - acc: 0.9848 - val_loss: 0.8432 - val_acc: 0.8331
#
# Epoch 00048: val_acc did not improve from 0.84850
# Epoch 49/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.0458 - acc: 0.9841 - val_loss: 0.7378 - val_acc: 0.8538
#
# Epoch 00049: val_acc improved from 0.84850 to 0.85380, saving model to assignment9.h5
# Epoch 50/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.0417 - acc: 0.9856 - val_loss: 0.7471 - val_acc: 0.8468
#
# Epoch 00050: val_acc did not improve from 0.85380
# Model took 2300.03 seconds to train
# Accuracy on test data is: 85.38

# %%
from keras.preprocessing import image

fig = plt.figure(figsize=(8,3))
random_image_index = [10, 30, 70, 90]
model = new_model
new_model.load_weights('assignment9.h5')

for i in enumerate(random_image_index):
  ax = fig.add_subplot(2, 5, 1 + i[0], xticks=[], yticks=[])
  img = test_features[i[1],:]
  
  x = np.expand_dims(img, axis=0)
  preds = model.predict(x)
  
  class_idx = np.argmax(preds[0])
  class_output = model.output[:, class_idx]
  last_conv_layer = model.get_layer("conv2d_19")
  
  grads = K.gradients(class_output, last_conv_layer.output)[0]
  pooled_grads = K.mean(grads, axis=(0, 1, 2))
  iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])
  pooled_grads_value, conv_layer_output_value = iterate([x])
  
  for i in range(256):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]

  heatmap = np.mean(conv_layer_output_value, axis=-1)
  heatmap = np.maximum(heatmap, 0)
  heatmap /= np.max(heatmap)
  
  heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
  heatmap = np.uint8(255 * heatmap)
  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
  superimposed_img = cv2.addWeighted(img, 0.75, heatmap, 0.25, 0, dtype=cv2.CV_32F)
  
  concatimg = cv2.hconcat([img, superimposed_img])
  plt.imshow(concatimg)
plt.show()
# Out:
# W0703 08:32:57.111636 140537785083776 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0703 08:32:57.710748 140537785083776 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0703 08:32:58.321287 140537785083776 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0703 08:32:58.944943 140537785083776 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Implementing Cutout in the original model and show the heat map

# %%
import numpy as np


def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.callbacks import EarlyStopping

datagen = ImageDataGenerator(zoom_range=0.0, horizontal_flip=False, preprocessing_function=get_random_eraser(v_l=0, v_h=1, pixel_level=True))
checkpointer = ModelCheckpoint(filepath='assignment9_cut_out.h5', verbose = 1, save_best_only=True, monitor='val_acc', mode='max')
lr_reducer = ReduceLROnPlateau(monitor='val_acc',factor=0.8, cooldown=0, patience=5, min_lr=0.5e-9,verbose = 1)

# train the model
start = time.time()

# Train the model
new_model_info = new_model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 256), samples_per_epoch = train_features.shape[0], nb_epoch = 50,
                                         validation_data = (test_features, test_labels), verbose=1, callbacks=[checkpointer, lr_reducer])
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))

# plot model history
plot_model_history(new_model_info)

# compute test accuracy
# Load the weights with the best validation accuracy:
new_model.load_weights('assignment9_cut_out.h5')
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, new_model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=195, epochs=50)`
# Epoch 1/50
# 195/195 [==============================] - 46s 238ms/step - loss: 0.3276 - acc: 0.8965 - val_loss: 0.5476 - val_acc: 0.8486
#
# Epoch 00001: val_acc improved from -inf to 0.84860, saving model to assignment9_cut_out.h5
# Epoch 2/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.2429 - acc: 0.9163 - val_loss: 0.5450 - val_acc: 0.8483
#
# Epoch 00002: val_acc did not improve from 0.84860
# Epoch 3/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.2286 - acc: 0.9218 - val_loss: 0.5522 - val_acc: 0.8455
#
# Epoch 00003: val_acc did not improve from 0.84860
# Epoch 4/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.2149 - acc: 0.9269 - val_loss: 0.4990 - val_acc: 0.8559
#
# Epoch 00004: val_acc improved from 0.84860 to 0.85590, saving model to assignment9_cut_out.h5
# Epoch 5/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.2078 - acc: 0.9268 - val_loss: 0.4850 - val_acc: 0.8652
#
# Epoch 00005: val_acc improved from 0.85590 to 0.86520, saving model to assignment9_cut_out.h5
# Epoch 6/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.2028 - acc: 0.9298 - val_loss: 0.5477 - val_acc: 0.8469
#
# Epoch 00006: val_acc did not improve from 0.86520
# Epoch 7/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.1985 - acc: 0.9314 - val_loss: 0.5256 - val_acc: 0.8554
#
# Epoch 00007: val_acc did not improve from 0.86520
# Epoch 8/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1992 - acc: 0.9309 - val_loss: 0.4874 - val_acc: 0.8594
#
# Epoch 00008: val_acc did not improve from 0.86520
# Epoch 9/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.1858 - acc: 0.9362 - val_loss: 0.5310 - val_acc: 0.8568
#
# Epoch 00009: val_acc did not improve from 0.86520
# Epoch 10/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1866 - acc: 0.9369 - val_loss: 0.4797 - val_acc: 0.8678
#
# Epoch 00010: val_acc improved from 0.86520 to 0.86780, saving model to assignment9_cut_out.h5
# Epoch 11/50
# 195/195 [==============================] - 46s 237ms/step - loss: 0.1829 - acc: 0.9372 - val_loss: 0.4879 - val_acc: 0.8629
#
# Epoch 00011: val_acc did not improve from 0.86780
# Epoch 12/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1826 - acc: 0.9367 - val_loss: 0.4886 - val_acc: 0.8652
#
# Epoch 00012: val_acc did not improve from 0.86780
# Epoch 13/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1735 - acc: 0.9399 - val_loss: 0.4895 - val_acc: 0.8667
#
# Epoch 00013: val_acc did not improve from 0.86780
# Epoch 14/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1738 - acc: 0.9420 - val_loss: 0.4876 - val_acc: 0.8674
#
# Epoch 00014: val_acc did not improve from 0.86780
# Epoch 15/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1738 - acc: 0.9417 - val_loss: 0.5266 - val_acc: 0.8631
#
# Epoch 00015: val_acc did not improve from 0.86780
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
# Epoch 16/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1600 - acc: 0.9440 - val_loss: 0.5080 - val_acc: 0.8654
#
# Epoch 00016: val_acc did not improve from 0.86780
# Epoch 17/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1586 - acc: 0.9442 - val_loss: 0.5013 - val_acc: 0.8622
#
# Epoch 00017: val_acc did not improve from 0.86780
# Epoch 18/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1579 - acc: 0.9466 - val_loss: 0.5260 - val_acc: 0.8549
#
# Epoch 00018: val_acc did not improve from 0.86780
# Epoch 19/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1516 - acc: 0.9483 - val_loss: 0.5084 - val_acc: 0.8627
#
# Epoch 00019: val_acc did not improve from 0.86780
# Epoch 20/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1508 - acc: 0.9478 - val_loss: 0.5050 - val_acc: 0.8637
#
# Epoch 00020: val_acc did not improve from 0.86780
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
# Epoch 21/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1448 - acc: 0.9506 - val_loss: 0.5062 - val_acc: 0.8674
#
# Epoch 00021: val_acc did not improve from 0.86780
# Epoch 22/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1416 - acc: 0.9510 - val_loss: 0.4718 - val_acc: 0.8758
#
# Epoch 00022: val_acc improved from 0.86780 to 0.87580, saving model to assignment9_cut_out.h5
# Epoch 23/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1419 - acc: 0.9518 - val_loss: 0.5425 - val_acc: 0.8609
#
# Epoch 00023: val_acc did not improve from 0.87580
# Epoch 24/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1443 - acc: 0.9508 - val_loss: 0.4980 - val_acc: 0.8676
#
# Epoch 00024: val_acc did not improve from 0.87580
# Epoch 25/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1359 - acc: 0.9531 - val_loss: 0.5568 - val_acc: 0.8602
#
# Epoch 00025: val_acc did not improve from 0.87580
# Epoch 26/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1357 - acc: 0.9532 - val_loss: 0.4897 - val_acc: 0.8762
#
# Epoch 00026: val_acc improved from 0.87580 to 0.87620, saving model to assignment9_cut_out.h5
# Epoch 27/50
# 195/195 [==============================] - 46s 237ms/step - loss: 0.1343 - acc: 0.9539 - val_loss: 0.5226 - val_acc: 0.8599
#
# Epoch 00027: val_acc did not improve from 0.87620
# Epoch 28/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1357 - acc: 0.9530 - val_loss: 0.5599 - val_acc: 0.8556
#
# Epoch 00028: val_acc did not improve from 0.87620
# Epoch 29/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1343 - acc: 0.9535 - val_loss: 0.4956 - val_acc: 0.8765
#
# Epoch 00029: val_acc improved from 0.87620 to 0.87650, saving model to assignment9_cut_out.h5
# Epoch 30/50
# 195/195 [==============================] - 46s 237ms/step - loss: 0.1344 - acc: 0.9541 - val_loss: 0.4940 - val_acc: 0.8701
#
# Epoch 00030: val_acc did not improve from 0.87650
# Epoch 31/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1259 - acc: 0.9563 - val_loss: 0.4918 - val_acc: 0.8730
#
# Epoch 00031: val_acc did not improve from 0.87650
# Epoch 32/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1329 - acc: 0.9547 - val_loss: 0.4743 - val_acc: 0.8776
#
# Epoch 00032: val_acc improved from 0.87650 to 0.87760, saving model to assignment9_cut_out.h5
# Epoch 33/50
# 195/195 [==============================] - 46s 237ms/step - loss: 0.1284 - acc: 0.9561 - val_loss: 0.4820 - val_acc: 0.8780
#
# Epoch 00033: val_acc improved from 0.87760 to 0.87800, saving model to assignment9_cut_out.h5
# Epoch 34/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1242 - acc: 0.9569 - val_loss: 0.4935 - val_acc: 0.8745
#
# Epoch 00034: val_acc did not improve from 0.87800
# Epoch 35/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1224 - acc: 0.9572 - val_loss: 0.4663 - val_acc: 0.8827
#
# Epoch 00035: val_acc improved from 0.87800 to 0.88270, saving model to assignment9_cut_out.h5
# Epoch 36/50
# 195/195 [==============================] - 46s 237ms/step - loss: 0.1283 - acc: 0.9557 - val_loss: 0.5290 - val_acc: 0.8710
#
# Epoch 00036: val_acc did not improve from 0.88270
# Epoch 37/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1237 - acc: 0.9573 - val_loss: 0.5034 - val_acc: 0.8738
#
# Epoch 00037: val_acc did not improve from 0.88270
# Epoch 38/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1235 - acc: 0.9571 - val_loss: 0.5070 - val_acc: 0.8715
#
# Epoch 00038: val_acc did not improve from 0.88270
# Epoch 39/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.1243 - acc: 0.9570 - val_loss: 0.4934 - val_acc: 0.8706
#
# Epoch 00039: val_acc did not improve from 0.88270
# Epoch 40/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.1255 - acc: 0.9569 - val_loss: 0.5003 - val_acc: 0.8728
#
# Epoch 00040: val_acc did not improve from 0.88270
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
# Epoch 41/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.1193 - acc: 0.9585 - val_loss: 0.4507 - val_acc: 0.8825
#
# Epoch 00041: val_acc did not improve from 0.88270
# Epoch 42/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.1198 - acc: 0.9584 - val_loss: 0.4588 - val_acc: 0.8803
#
# Epoch 00042: val_acc did not improve from 0.88270
# Epoch 43/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1180 - acc: 0.9598 - val_loss: 0.4770 - val_acc: 0.8796
#
# Epoch 00043: val_acc did not improve from 0.88270
# Epoch 44/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1138 - acc: 0.9607 - val_loss: 0.5001 - val_acc: 0.8758
#
# Epoch 00044: val_acc did not improve from 0.88270
# Epoch 45/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.1139 - acc: 0.9606 - val_loss: 0.4894 - val_acc: 0.8733
#
# Epoch 00045: val_acc did not improve from 0.88270
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
# Epoch 46/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.1154 - acc: 0.9610 - val_loss: 0.4651 - val_acc: 0.8816
#
# Epoch 00046: val_acc did not improve from 0.88270
# Epoch 47/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.1048 - acc: 0.9642 - val_loss: 0.4714 - val_acc: 0.8820
#
# Epoch 00047: val_acc did not improve from 0.88270
# Epoch 48/50
# 195/195 [==============================] - 46s 236ms/step - loss: 0.1050 - acc: 0.9641 - val_loss: 0.4762 - val_acc: 0.8808
#
# Epoch 00048: val_acc did not improve from 0.88270
# Epoch 49/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.1108 - acc: 0.9617 - val_loss: 0.4778 - val_acc: 0.8803
#
# Epoch 00049: val_acc did not improve from 0.88270
# Epoch 50/50
# 195/195 [==============================] - 46s 235ms/step - loss: 0.1012 - acc: 0.9644 - val_loss: 0.4782 - val_acc: 0.8835
#
# Epoch 00050: val_acc improved from 0.88270 to 0.88350, saving model to assignment9_cut_out.h5
# Model took 2302.68 seconds to train
# Accuracy on test data is: 88.35

# %%
from keras.preprocessing import image

fig = plt.figure(figsize=(8,3))
random_image_index = [10, 30, 70, 90]
model = new_model

for i in enumerate(random_image_index):
  ax = fig.add_subplot(2, 5, 1 + i[0], xticks=[], yticks=[])
  img = test_features[i[1],:]
  
  x = np.expand_dims(img, axis=0)
  preds = model.predict(x)
  
  class_idx = np.argmax(preds[0])
  class_output = model.output[:, class_idx]
  last_conv_layer = model.get_layer("conv2d_19")
  
  grads = K.gradients(class_output, last_conv_layer.output)[0]
  pooled_grads = K.mean(grads, axis=(0, 1, 2))
  iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])
  pooled_grads_value, conv_layer_output_value = iterate([x])
  
  for i in range(256):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]

  heatmap = np.mean(conv_layer_output_value, axis=-1)
  heatmap = np.maximum(heatmap, 0)
  heatmap /= np.max(heatmap)
  
  heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
  heatmap = np.uint8(255 * heatmap)
  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
  superimposed_img = cv2.addWeighted(img, 0.6, heatmap, 0.4, 0, dtype=cv2.CV_32F)
  
  concatimg = cv2.hconcat([img, superimposed_img])
  plt.imshow(concatimg)
plt.show()
# Out:
# W0703 09:22:17.280861 140537785083776 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0703 09:22:17.874679 140537785083776 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0703 09:22:18.632997 140537785083776 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0703 09:22:19.325018 140537785083776 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Result Comparision:
#
#
# 1.   ### Model with cut out has better validation accuracy than model without cutout
# 2.   ### In Model with cut out identifies very small details in an image, example in image 3 it identifies the eye of the bird and fir image 1 it identifies the entire aeroplane strucutre not only wings.
