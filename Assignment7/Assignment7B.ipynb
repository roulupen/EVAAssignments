# %% [markdown]
# <a href="https://colab.research.google.com/github/roulupen/EVAAssignments/blob/master/Assignment7/Assignment7B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
def space_to_depth_x2(x):
    """Thin wrapper for Tensorflow space_to_depth with block_size=2."""
    # Import currently required to make Lambda work.
    # See: https://github.com/fchollet/keras/issues/5088#issuecomment-273851273
    import tensorflow as tf
    return tf.space_to_depth(x, block_size=2)

# %%
def space_to_depth_x2_output_shape(input_shape):
    """Determine space_to_depth output shape for block_size=2.

    Note: For Lambda with TensorFlow backend, output shape may not be needed.
    """
    return (input_shape[0], input_shape[1] // 2, input_shape[2] // 2, 4 *
            input_shape[3]) if input_shape[1] else (input_shape[0], None, None,
                                                    4 * input_shape[3])

# %%
from keras.layers import Input, Conv2D, SeparableConv2D, DepthwiseConv2D, AveragePooling2D, Concatenate, BatchNormalization, MaxPooling2D, Lambda
from keras import regularizers
from keras.models import Model
from keras.layers.merge import concatenate

model_input = Input(shape=(32, 32, 3))


x1 = SeparableConv2D(32, (5, 5), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.001))(model_input)
x1 = BatchNormalization()(x1)

x2 = Conv2D(64, (5, 5), activation='relu', padding='same',kernel_regularizer=regularizers.l2(0.001))(x1)
x2 = BatchNormalization()(x2)

x3_input = Conv2D(16, 1, activation='relu')(x2)
x3 = Conv2D(32, (5, 5), activation='relu', padding='same',kernel_regularizer=regularizers.l2(0.001))(x3_input)
x3 = BatchNormalization()(x3)

x4_input = Conv2D(32, 1, activation='relu')(concatenate([x3, x1]))
x4 = SeparableConv2D(64, (5, 5), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.001))(x4_input)
x4 = BatchNormalization()(x4)

x5 = MaxPooling2D((2,2))(concatenate([x4, x1]))
x5 = Conv2D(16, 1, activation='relu')(x5) #1x1 convolution to decrease the number of channel
x5 = Dropout(0.25)(x5)

# Adding space to depth to reshape output
x1 = Lambda( space_to_depth_x2, output_shape=space_to_depth_x2_output_shape)(x1)
x2 = Lambda( space_to_depth_x2, output_shape=space_to_depth_x2_output_shape)(x2)
x4 = Lambda( space_to_depth_x2, output_shape=space_to_depth_x2_output_shape)(x4)
x3 = Lambda( space_to_depth_x2, output_shape=space_to_depth_x2_output_shape)(x3)

x6 = SeparableConv2D(32, (5, 5), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.001))(x5)
x6 = BatchNormalization()(x6)

x7_input = Conv2D(32, 1, activation='relu')(concatenate([x6, x4, x1]))
x7 = Conv2D(64, (5, 5), activation='relu', padding='same',kernel_regularizer=regularizers.l2(0.001))(x7_input)
x7 = BatchNormalization()(x7)

x8_input = Conv2D(16, 1, activation='relu')(concatenate([x7, x6, x4, x3]))
x8 = SeparableConv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.001))(x8_input)
x8 = BatchNormalization()(x8)

x9_input = Conv2D(16, 1, activation='relu')(concatenate([x8, x7, x6, x4, x3, x1]))
x9 = SeparableConv2D(32, (5, 5), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.001))(x9_input)
x9 = BatchNormalization()(x9)


x10 = MaxPooling2D((2,2))(concatenate([x9,x8,x6,x4,x1]))
x10 = Conv2D(32, 1, activation='relu')(x10) #1x1 convolution to decrease the number of channel
x10 = Dropout(0.25)(x10)

# Adding space to depth to reshape output
x7 = Lambda( space_to_depth_x2, output_shape=space_to_depth_x2_output_shape)(x7)
x8 = Lambda( space_to_depth_x2, output_shape=space_to_depth_x2_output_shape)(x8)
x4 = Lambda( space_to_depth_x2, output_shape=space_to_depth_x2_output_shape)(x4)
x2 = Lambda( space_to_depth_x2, output_shape=space_to_depth_x2_output_shape)(x2)
x6 = Lambda( space_to_depth_x2, output_shape=space_to_depth_x2_output_shape)(x6)
x3 = Lambda( space_to_depth_x2, output_shape=space_to_depth_x2_output_shape)(x3)
x1 = Lambda( space_to_depth_x2, output_shape=space_to_depth_x2_output_shape)(x1)

x11_input = Conv2D(32, 1, activation='relu')(concatenate([x10,x7]))
x11= Conv2D(64, (5, 5), activation='relu', padding='same',kernel_regularizer=regularizers.l2(0.001))(x11_input)
x11 = BatchNormalization()(x11)

x12_input = Conv2D(16, 1, activation='relu')(concatenate([x11, x8, x4, x2]))
x12 = SeparableConv2D(32, (5, 5), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.001))(x12_input)
x12 = BatchNormalization()(x12)

x13_input = Conv2D(16, 1, activation='relu')(concatenate([x12,x11, x6, x3, x2]))
x13= Conv2D(32, (3, 3), activation='relu', padding='same',kernel_regularizer=regularizers.l2(0.001))(x13_input)
x13 = BatchNormalization()(x13)

x14_input = Conv2D(16, 1, activation='relu')(concatenate([x13, x12, x8, x6, x4, x3, x1]))
x14 = SeparableConv2D(32, (5, 5), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.001))(x14_input)
x14 = BatchNormalization()(x14)
x14 = Dropout(0.25)(x14)

x15 = AveragePooling2D((8,8))(x14)
x15 = Conv2D(10, 1, activation='relu')(x15) # Reduce number of channel


x15 = Flatten()(x15)
model_output = Activation(activation='softmax')(x15)


model = Model(model_input, model_output, name='assignment7b')

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# separable_conv2d_50 (SeparableC (None, 32, 32, 32)   203         input_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 32, 32, 32)   128         separable_conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 32, 32, 64)   51264       batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 32, 32, 64)   256         conv2d_115[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 32, 32, 16)   1040        batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 32, 32, 32)   12832       conv2d_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 32, 32, 32)   128         conv2d_117[0][0]
# __________________________________________________________________________________________________
# concatenate_70 (Concatenate)    (None, 32, 32, 64)   0           batch_normalization_87[0][0]
#                                                                  batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 32, 32, 32)   2080        concatenate_70[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_51 (SeparableC (None, 32, 32, 64)   2912        conv2d_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 32, 32, 64)   256         separable_conv2d_51[0][0]
# __________________________________________________________________________________________________
# concatenate_71 (Concatenate)    (None, 32, 32, 96)   0           batch_normalization_88[0][0]
#                                                                  batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 16, 16, 96)   0           concatenate_71[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 16, 16, 16)   1552        max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 16, 16, 16)   0           conv2d_119[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_52 (SeparableC (None, 16, 16, 32)   944         dropout_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 16, 16, 32)   128         separable_conv2d_52[0][0]
# __________________________________________________________________________________________________
# lambda_80 (Lambda)              (None, 16, 16, 256)  0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# lambda_78 (Lambda)              (None, 16, 16, 128)  0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# concatenate_72 (Concatenate)    (None, 16, 16, 416)  0           batch_normalization_89[0][0]
#                                                                  lambda_80[0][0]
#                                                                  lambda_78[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 16, 16, 32)   13344       concatenate_72[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 16, 16, 64)   51264       conv2d_120[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 16, 16, 64)   256         conv2d_121[0][0]
# __________________________________________________________________________________________________
# lambda_81 (Lambda)              (None, 16, 16, 128)  0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# concatenate_73 (Concatenate)    (None, 16, 16, 480)  0           batch_normalization_90[0][0]
#                                                                  batch_normalization_89[0][0]
#                                                                  lambda_80[0][0]
#                                                                  lambda_81[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 16, 16, 16)   7696        concatenate_73[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_53 (SeparableC (None, 16, 16, 32)   688         conv2d_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 16, 16, 32)   128         separable_conv2d_53[0][0]
# __________________________________________________________________________________________________
# concatenate_74 (Concatenate)    (None, 16, 16, 640)  0           batch_normalization_91[0][0]
#                                                                  batch_normalization_90[0][0]
#                                                                  batch_normalization_89[0][0]
#                                                                  lambda_80[0][0]
#                                                                  lambda_81[0][0]
#                                                                  lambda_78[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 16, 16, 16)   10256       concatenate_74[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_54 (SeparableC (None, 16, 16, 32)   944         conv2d_123[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 16, 16, 32)   128         separable_conv2d_54[0][0]
# __________________________________________________________________________________________________
# concatenate_75 (Concatenate)    (None, 16, 16, 480)  0           batch_normalization_92[0][0]
#                                                                  batch_normalization_91[0][0]
#                                                                  batch_normalization_89[0][0]
#                                                                  lambda_80[0][0]
#                                                                  lambda_78[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 8, 8, 480)    0           concatenate_75[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 8, 8, 32)     15392       max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 8, 8, 32)     0           conv2d_124[0][0]
# __________________________________________________________________________________________________
# lambda_82 (Lambda)              (None, 8, 8, 256)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# concatenate_76 (Concatenate)    (None, 8, 8, 288)    0           dropout_23[0][0]
#                                                                  lambda_82[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 8, 8, 32)     9248        concatenate_76[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 8, 8, 64)     51264       conv2d_125[0][0]
# __________________________________________________________________________________________________
# lambda_79 (Lambda)              (None, 16, 16, 256)  0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 64)     256         conv2d_126[0][0]
# __________________________________________________________________________________________________
# lambda_83 (Lambda)              (None, 8, 8, 128)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# lambda_84 (Lambda)              (None, 8, 8, 1024)   0           lambda_80[0][0]
# __________________________________________________________________________________________________
# lambda_85 (Lambda)              (None, 8, 8, 1024)   0           lambda_79[0][0]
# __________________________________________________________________________________________________
# concatenate_77 (Concatenate)    (None, 8, 8, 2240)   0           batch_normalization_93[0][0]
#                                                                  lambda_83[0][0]
#                                                                  lambda_84[0][0]
#                                                                  lambda_85[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 8, 8, 16)     35856       concatenate_77[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_55 (SeparableC (None, 8, 8, 32)     944         conv2d_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 8, 8, 32)     128         separable_conv2d_55[0][0]
# __________________________________________________________________________________________________
# lambda_86 (Lambda)              (None, 8, 8, 128)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# lambda_87 (Lambda)              (None, 8, 8, 512)    0           lambda_81[0][0]
# __________________________________________________________________________________________________
# concatenate_78 (Concatenate)    (None, 8, 8, 1760)   0           batch_normalization_94[0][0]
#                                                                  batch_normalization_93[0][0]
#                                                                  lambda_86[0][0]
#                                                                  lambda_87[0][0]
#                                                                  lambda_85[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 8, 8, 16)     28176       concatenate_78[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 8, 8, 32)     4640        conv2d_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 8, 8, 32)     128         conv2d_129[0][0]
# __________________________________________________________________________________________________
# lambda_88 (Lambda)              (None, 8, 8, 512)    0           lambda_78[0][0]
# __________________________________________________________________________________________________
# concatenate_79 (Concatenate)    (None, 8, 8, 2368)   0           batch_normalization_95[0][0]
#                                                                  batch_normalization_94[0][0]
#                                                                  lambda_83[0][0]
#                                                                  lambda_86[0][0]
#                                                                  lambda_84[0][0]
#                                                                  lambda_87[0][0]
#                                                                  lambda_88[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 8, 8, 16)     37904       concatenate_79[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_56 (SeparableC (None, 8, 8, 32)     944         conv2d_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 8, 8, 32)     128         separable_conv2d_56[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 8, 8, 32)     0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 1, 1, 32)     0           dropout_24[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 1, 1, 10)     330         average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 10)           0           conv2d_131[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 10)           0           flatten_8[0][0]
# ==================================================================================================
# Total params: 343,765
# Trainable params: 342,741
# Non-trainable params: 1,024
# __________________________________________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)

checkpointer = ModelCheckpoint(filepath='assignment7b.h5', verbose = 1, save_best_only=True, monitor='val_acc', mode='max')


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 512),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 10, 
                                 validation_data = (test_features, test_labels), verbose=1, callbacks=[checkpointer])
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
# Load the weights with the best validation accuracy:
model.load_weights('assignment7b.h5')
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=97, epochs=10)`
#   app.launch_new_instance()
# W0616 05:59:39.335447 140428221081472 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/10
# 97/97 [==============================] - 1934s 20s/step - loss: 1.8507 - acc: 0.3828 - val_loss: 2.0616 - val_acc: 0.3793
#
# Epoch 00001: val_acc improved from -inf to 0.37930, saving model to assignment7b.h5
# Epoch 2/10
# 97/97 [==============================] - 1900s 20s/step - loss: 1.3072 - acc: 0.5731 - val_loss: 1.5235 - val_acc: 0.5239
#
# Epoch 00002: val_acc improved from 0.37930 to 0.52390, saving model to assignment7b.h5
# Epoch 3/10
# 97/97 [==============================] - 1896s 20s/step - loss: 1.0681 - acc: 0.6571 - val_loss: 1.3998 - val_acc: 0.5648
#
# Epoch 00003: val_acc improved from 0.52390 to 0.56480, saving model to assignment7b.h5
# Epoch 4/10
# 97/97 [==============================] - 1891s 19s/step - loss: 0.9318 - acc: 0.7039 - val_loss: 1.4453 - val_acc: 0.5815
#
# Epoch 00004: val_acc improved from 0.56480 to 0.58150, saving model to assignment7b.h5
# Epoch 5/10
# 97/97 [==============================] - 1886s 19s/step - loss: 0.8379 - acc: 0.7397 - val_loss: 1.1326 - val_acc: 0.6420
#
# Epoch 00005: val_acc improved from 0.58150 to 0.64200, saving model to assignment7b.h5
# Epoch 6/10
# 97/97 [==============================] - 1886s 19s/step - loss: 0.7550 - acc: 0.7682 - val_loss: 1.4129 - val_acc: 0.5850
#
# Epoch 00006: val_acc did not improve from 0.64200
# Epoch 7/10
# 97/97 [==============================] - 1884s 19s/step - loss: 0.6936 - acc: 0.7933 - val_loss: 0.9625 - val_acc: 0.7103
#
# Epoch 00007: val_acc improved from 0.64200 to 0.71030, saving model to assignment7b.h5
# Epoch 8/10
# 97/97 [==============================] - 1896s 20s/step - loss: 0.6251 - acc: 0.8177 - val_loss: 1.1046 - val_acc: 0.6709
#
# Epoch 00008: val_acc did not improve from 0.71030
# Epoch 9/10
# 97/97 [==============================] - 1911s 20s/step - loss: 0.5796 - acc: 0.8336 - val_loss: 1.3783 - val_acc: 0.6200
#
# Epoch 00009: val_acc did not improve from 0.71030
# Epoch 10/10
# 97/97 [==============================] - 1910s 20s/step - loss: 0.5393 - acc: 0.8499 - val_loss: 1.2634 - val_acc: 0.6546
#
# Epoch 00010: val_acc did not improve from 0.71030
# Model took 19009.38 seconds to train
# Accuracy on test data is: 71.03
