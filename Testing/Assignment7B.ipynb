# %% [markdown]
# <a href="https://colab.research.google.com/github/roulupen/EVAAssignments/blob/master/Testing/Assignment7B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
def space_to_depth_x2(x):
    """Thin wrapper for Tensorflow space_to_depth with block_size=2."""
    # Import currently required to make Lambda work.
    # See: https://github.com/fchollet/keras/issues/5088#issuecomment-273851273
    import tensorflow as tf
    return tf.space_to_depth(x, block_size=2)

# %%
def space_to_depth_x2_output_shape(input_shape):
    """Determine space_to_depth output shape for block_size=2.

    Note: For Lambda with TensorFlow backend, output shape may not be needed.
    """
    return (input_shape[0], input_shape[1] // 2, input_shape[2] // 2, 4 *
            input_shape[3]) if input_shape[1] else (input_shape[0], None, None,
                                                    4 * input_shape[3])

# %%
from keras.layers import Input, Conv2D, SeparableConv2D, DepthwiseConv2D, AveragePooling2D, Concatenate, BatchNormalization, MaxPooling2D, Lambda
from keras import regularizers
from keras.models import Model
from keras.layers.merge import concatenate


weight_decay = 1e-4

model_input = Input(shape=(32, 32, 3))

x1 = SeparableConv2D(32, (5, 5), activation='relu', padding='same', kernel_regularizer=regularizers.l2(weight_decay))(model_input)
x1 = BatchNormalization()(x1)

x2 = Conv2D(64, (5, 5), activation='relu', padding='same', kernel_regularizer=regularizers.l2(weight_decay))(x1)
x2 = BatchNormalization()(x2)

x3 = Conv2D(128, (5, 5), activation='relu', padding='same', kernel_regularizer=regularizers.l2(weight_decay))(x2)
x3 = BatchNormalization()(x3)

x4_input = Conv2D(128, 1, activation='relu')(concatenate([x3, x1]))
x4 = SeparableConv2D(256, (5, 5), activation='relu', padding='same', kernel_regularizer=regularizers.l2(weight_decay))(x4_input)
x4 = BatchNormalization()(x4)

x5 = MaxPooling2D((2,2))(concatenate([x4, x1]))
x5 = Conv2D(64, 1, activation='relu')(x5) #1x1 convolution to decrease the number of channel
x5 = Dropout(0.25)(x5)

# Adding space to depth to reshape output
x1 = Lambda( space_to_depth_x2, output_shape=space_to_depth_x2_output_shape)(x1)
x2 = Lambda( space_to_depth_x2, output_shape=space_to_depth_x2_output_shape)(x2)
x4 = Lambda( space_to_depth_x2, output_shape=space_to_depth_x2_output_shape)(x4)
x3 = Lambda( space_to_depth_x2, output_shape=space_to_depth_x2_output_shape)(x3)

x6 = SeparableConv2D(64, (5, 5), activation='relu', padding='same', kernel_regularizer=regularizers.l2(weight_decay))(x5)
x6 = BatchNormalization()(x6)

x7_input = Conv2D(32, 1, activation='relu')(concatenate([x6, x4, x1]))
x7 = Conv2D(64, (5, 5), activation='relu', padding='same',kernel_regularizer=regularizers.l2(weight_decay))(x7_input)
x7 = BatchNormalization()(x7)

x8_input = Conv2D(16, 1, activation='relu')(concatenate([x7, x6, x4, x3]))
x8_input = Dropout(0.3)(x8_input)
x8 = SeparableConv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(weight_decay))(x8_input)
x8 = BatchNormalization()(x8)

x9_input = Conv2D(16, 1, activation='relu')(concatenate([x8, x7, x6, x4, x3, x1]))
x9_input = Dropout(0.3)(x9_input)
x9 = SeparableConv2D(32, (5, 5), activation='relu', padding='same', kernel_regularizer=regularizers.l2(weight_decay))(x9_input)
x9 = BatchNormalization()(x9)


x10 = MaxPooling2D((2,2))(concatenate([x9,x8,x6,x4,x1]))
x10 = Conv2D(32, 1, activation='relu')(x10) #1x1 convolution to decrease the number of channel
x10 = Dropout(0.4)(x10)

# Adding space to depth to reshape output
x7 = Lambda( space_to_depth_x2, output_shape=space_to_depth_x2_output_shape)(x7)
x8 = Lambda( space_to_depth_x2, output_shape=space_to_depth_x2_output_shape)(x8)
x4 = Lambda( space_to_depth_x2, output_shape=space_to_depth_x2_output_shape)(x4)
x2 = Lambda( space_to_depth_x2, output_shape=space_to_depth_x2_output_shape)(x2)
x6 = Lambda( space_to_depth_x2, output_shape=space_to_depth_x2_output_shape)(x6)
x3 = Lambda( space_to_depth_x2, output_shape=space_to_depth_x2_output_shape)(x3)
x1 = Lambda( space_to_depth_x2, output_shape=space_to_depth_x2_output_shape)(x1)

x11_input = Conv2D(32, 1, activation='relu')(concatenate([x10,x7]))
x11= Conv2D(64, (5, 5), activation='relu', padding='same',kernel_regularizer=regularizers.l2(weight_decay))(x11_input)
x11 = BatchNormalization()(x11)

x12_input = Conv2D(64, 1, activation='relu')(concatenate([x11, x8, x4, x2]))
x12_input = Dropout(0.4)(x12_input)
x12 = SeparableConv2D(128, (5, 5), activation='relu', padding='same', kernel_regularizer=regularizers.l2(weight_decay))(x12_input)
x12 = BatchNormalization()(x12)

x13_input = Conv2D(256, 1, activation='relu')(concatenate([x12,x11, x6, x3, x2]))
x13_input = Dropout(0.4)(x13_input)
x13= Conv2D(256, (3, 3), activation='relu', padding='same',kernel_regularizer=regularizers.l2(weight_decay))(x13_input)
x13 = BatchNormalization()(x13)

x14_input = Conv2D(128, 1, activation='relu')(concatenate([x13, x12, x8, x6, x4, x3, x1]))
x14 = SeparableConv2D(256, (5, 5), activation='relu', padding='same', kernel_regularizer=regularizers.l2(weight_decay))(x14_input)
x14 = BatchNormalization()(x14)

x15 = AveragePooling2D((8,8))(x14)
x15 = Conv2D(10, 1, activation='relu')(x15) # Reduce number of channel


x15 = Flatten()(x15)
model_output = Activation(activation='softmax')(x15)


model = Model(model_input, model_output, name='assignment7b')

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0618 15:08:11.034997 139784341968768 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0618 15:08:11.039550 139784341968768 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0618 15:08:11.050895 139784341968768 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0618 15:08:11.098242 139784341968768 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0618 15:08:11.099185 139784341968768 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0618 15:08:12.783128 139784341968768 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0618 15:08:13.235560 139784341968768 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0618 15:08:13.257072 139784341968768 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0618 15:08:14.178893 139784341968768 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3980: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# W0618 15:08:14.203524 139784341968768 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 32, 32, 32)   203         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 32)   128         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 64)   51264       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 128)  204928      batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 128)  512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 160)  0           batch_normalization_3[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 128)  20608       concatenate_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 32, 32, 256)  36224       conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 256)  1024        separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 288)  0           batch_normalization_4[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 288)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 64)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 16, 16, 64)   5760        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 64)   256         separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 16, 16, 1024) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 16, 16, 128)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 1216) 0           batch_normalization_5[0][0]
#                                                                  lambda_3[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 32)   38944       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 64)   51264       conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 16, 16, 512)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 16, 16, 1664) 0           batch_normalization_6[0][0]
#                                                                  batch_normalization_5[0][0]
#                                                                  lambda_3[0][0]
#                                                                  lambda_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 16)   26640       concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 16)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 16, 16, 32)   688         dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 32)   128         separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 16, 16, 1824) 0           batch_normalization_7[0][0]
#                                                                  batch_normalization_6[0][0]
#                                                                  batch_normalization_5[0][0]
#                                                                  lambda_3[0][0]
#                                                                  lambda_4[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 16)   29200       concatenate_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 16)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 16, 16, 32)   944         dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 32)   128         separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 16, 16, 1280) 0           batch_normalization_8[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_5[0][0]
#                                                                  lambda_3[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 1280)   0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 32)     40992       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 32)     0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 8, 8, 256)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 8, 8, 288)    0           dropout_4[0][0]
#                                                                  lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 32)     9248        concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 64)     51264       conv2d_10[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 16, 16, 256)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 64)     256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 8, 8, 128)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 8, 8, 4096)   0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 8, 8, 1024)   0           lambda_2[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 8, 8, 5312)   0           batch_normalization_9[0][0]
#                                                                  lambda_6[0][0]
#                                                                  lambda_7[0][0]
#                                                                  lambda_8[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 64)     340032      concatenate_8[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 8, 8, 64)     0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_6 (SeparableCo (None, 8, 8, 128)    9920        dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 128)    512         separable_conv2d_6[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 8, 8, 256)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 8, 8, 2048)   0           lambda_4[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 8, 8, 3520)   0           batch_normalization_10[0][0]
#                                                                  batch_normalization_9[0][0]
#                                                                  lambda_9[0][0]
#                                                                  lambda_10[0][0]
#                                                                  lambda_8[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 256)    901376      concatenate_9[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 8, 8, 256)    0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 256)    590080      dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 256)    1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 8, 8, 512)    0           lambda_1[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 8, 8, 7424)   0           batch_normalization_11[0][0]
#                                                                  batch_normalization_10[0][0]
#                                                                  lambda_6[0][0]
#                                                                  lambda_9[0][0]
#                                                                  lambda_7[0][0]
#                                                                  lambda_10[0][0]
#                                                                  lambda_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 128)    950400      concatenate_10[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_7 (SeparableCo (None, 8, 8, 256)    36224       conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 256)    1024        separable_conv2d_7[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 256)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 1, 1, 10)     2570        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 10)           0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 10)           0           flatten_1[0][0]
# ==================================================================================================
# Total params: 3,422,773
# Trainable params: 3,420,021
# Non-trainable params: 2,752
# __________________________________________________________________________________________________

# %%
def lr_schedule(epoch):
    lrate = 0.001
    if epoch > 30:
      lrate = 0.0005
    if epoch > 50:
      lrate = 0.0003
    if epoch > 60:
      lrate = 0.0001
    if epoch > 70:
      lrate = 0.00001
    if epoch > 90:
      lrate = 0.000001
    if epoch > 100:
      lrate = 0.0000001
    return lrate

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
from keras.callbacks import LearningRateScheduler, ReduceLROnPlateau

data_augmentation = True

if not data_augmentation:
  datagen = ImageDataGenerator(zoom_range=0.0, horizontal_flip=False)
else:
  datagen = ImageDataGenerator(
            featurewise_center=False,  # set input mean to 0 over the dataset
            samplewise_center=False,  # set each sample mean to 0
            featurewise_std_normalization=False,  # divide inputs by std of the dataset
            samplewise_std_normalization=False,  # divide each input by its std
            rotation_range=15,
            zoom_range = 0.05, 
            width_shift_range=0.2,
            height_shift_range=0.2,
            horizontal_flip=True,
            vertical_flip=False,
            zca_whitening=False)
#datagen = ImageDataGenerator( rotation_range=90,
#                 width_shift_range=0.1, height_shift_range=0.1,
#                 horizontal_flip=True)
#datagen = ImageDataGenerator(
#        featurewise_center=False,  # set input mean to 0 over the dataset
#        samplewise_center=False,  # set each sample mean to 0
#        featurewise_std_normalization=False,  # divide inputs by std of the dataset
#        samplewise_std_normalization=False,  # divide each input by its std
#        zca_whitening = False ,   # apply ZCA whitening
#        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
#        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
#        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
#        horizontal_flip=True,  # randomly flip images
#        vertical_flip=False)

checkpointer = ModelCheckpoint(filepath='assignment7b.h5', verbose = 1, save_best_only=True, monitor='val_acc', mode='max')
#reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, verbose=0, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)
reduce_lr = LearningRateScheduler(lr_schedule)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 512),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 125, 
                                 validation_data = (test_features, test_labels), verbose=1, callbacks=[checkpointer, reduce_lr])
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
# Load the weights with the best validation accuracy:
model.load_weights('assignment7b.h5')
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=97, epochs=125)`
# W0618 15:08:22.557189 139784341968768 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/125
# 97/97 [==============================] - 107s 1s/step - loss: 1.6353 - acc: 0.4263 - val_loss: 1.7005 - val_acc: 0.4551
#
# Epoch 00001: val_acc improved from -inf to 0.45510, saving model to assignment7b.h5
# Epoch 2/125
# 97/97 [==============================] - 97s 997ms/step - loss: 1.2469 - acc: 0.5726 - val_loss: 1.3192 - val_acc: 0.5645
#
# Epoch 00002: val_acc improved from 0.45510 to 0.56450, saving model to assignment7b.h5
# Epoch 3/125
# 97/97 [==============================] - 90s 932ms/step - loss: 1.0632 - acc: 0.6403 - val_loss: 1.0396 - val_acc: 0.6560
#
# Epoch 00003: val_acc improved from 0.56450 to 0.65600, saving model to assignment7b.h5
# Epoch 4/125
# 97/97 [==============================] - 90s 932ms/step - loss: 0.9271 - acc: 0.6904 - val_loss: 1.1169 - val_acc: 0.6666
#
# Epoch 00004: val_acc improved from 0.65600 to 0.66660, saving model to assignment7b.h5
# Epoch 5/125
# 97/97 [==============================] - 90s 932ms/step - loss: 0.8268 - acc: 0.7270 - val_loss: 0.9278 - val_acc: 0.7097
#
# Epoch 00005: val_acc improved from 0.66660 to 0.70970, saving model to assignment7b.h5
# Epoch 6/125
# 97/97 [==============================] - 90s 931ms/step - loss: 0.7585 - acc: 0.7514 - val_loss: 0.9820 - val_acc: 0.7147
#
# Epoch 00006: val_acc improved from 0.70970 to 0.71470, saving model to assignment7b.h5
# Epoch 7/125
# 97/97 [==============================] - 90s 931ms/step - loss: 0.6998 - acc: 0.7724 - val_loss: 0.7910 - val_acc: 0.7625
#
# Epoch 00007: val_acc improved from 0.71470 to 0.76250, saving model to assignment7b.h5
# Epoch 8/125
# 97/97 [==============================] - 90s 930ms/step - loss: 0.6519 - acc: 0.7918 - val_loss: 0.9473 - val_acc: 0.7325
#
# Epoch 00008: val_acc did not improve from 0.76250
# Epoch 9/125
# 97/97 [==============================] - 90s 929ms/step - loss: 0.6121 - acc: 0.8064 - val_loss: 0.7463 - val_acc: 0.7779
#
# Epoch 00009: val_acc improved from 0.76250 to 0.77790, saving model to assignment7b.h5
# Epoch 10/125
# 97/97 [==============================] - 90s 930ms/step - loss: 0.5809 - acc: 0.8175 - val_loss: 0.9297 - val_acc: 0.7237
#
# Epoch 00010: val_acc did not improve from 0.77790
# Epoch 11/125
# 97/97 [==============================] - 90s 930ms/step - loss: 0.5553 - acc: 0.8262 - val_loss: 0.9581 - val_acc: 0.7294
#
# Epoch 00011: val_acc did not improve from 0.77790
# Epoch 12/125
# 97/97 [==============================] - 90s 931ms/step - loss: 0.5325 - acc: 0.8348 - val_loss: 0.6572 - val_acc: 0.8050
#
# Epoch 00012: val_acc improved from 0.77790 to 0.80500, saving model to assignment7b.h5
# Epoch 13/125
# 97/97 [==============================] - 90s 931ms/step - loss: 0.5077 - acc: 0.8421 - val_loss: 0.6102 - val_acc: 0.8201
#
# Epoch 00013: val_acc improved from 0.80500 to 0.82010, saving model to assignment7b.h5
# Epoch 14/125
# 97/97 [==============================] - 90s 931ms/step - loss: 0.4854 - acc: 0.8522 - val_loss: 0.9086 - val_acc: 0.7508
#
# Epoch 00014: val_acc did not improve from 0.82010
# Epoch 15/125
# 97/97 [==============================] - 90s 930ms/step - loss: 0.4750 - acc: 0.8566 - val_loss: 0.6548 - val_acc: 0.8165
#
# Epoch 00015: val_acc did not improve from 0.82010
# Epoch 16/125
# 97/97 [==============================] - 90s 929ms/step - loss: 0.4572 - acc: 0.8626 - val_loss: 0.6872 - val_acc: 0.8031
#
# Epoch 00016: val_acc did not improve from 0.82010
# Epoch 17/125
# 97/97 [==============================] - 90s 930ms/step - loss: 0.4397 - acc: 0.8680 - val_loss: 0.5664 - val_acc: 0.8364
#
# Epoch 00017: val_acc improved from 0.82010 to 0.83640, saving model to assignment7b.h5
# Epoch 18/125
# 97/97 [==============================] - 90s 929ms/step - loss: 0.4348 - acc: 0.8710 - val_loss: 0.5612 - val_acc: 0.8348
#
# Epoch 00018: val_acc did not improve from 0.83640
# Epoch 19/125
# 97/97 [==============================] - 90s 928ms/step - loss: 0.4251 - acc: 0.8754 - val_loss: 0.5601 - val_acc: 0.8418
#
# Epoch 00019: val_acc improved from 0.83640 to 0.84180, saving model to assignment7b.h5
# Epoch 20/125
# 97/97 [==============================] - 90s 928ms/step - loss: 0.4067 - acc: 0.8800 - val_loss: 0.5631 - val_acc: 0.8359
#
# Epoch 00020: val_acc did not improve from 0.84180
# Epoch 21/125
# 97/97 [==============================] - 90s 928ms/step - loss: 0.3977 - acc: 0.8822 - val_loss: 0.5962 - val_acc: 0.8277
#
# Epoch 00021: val_acc did not improve from 0.84180
# Epoch 22/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.3877 - acc: 0.8882 - val_loss: 0.6115 - val_acc: 0.8258
#
# Epoch 00022: val_acc did not improve from 0.84180
# Epoch 23/125
# 97/97 [==============================] - 90s 928ms/step - loss: 0.3804 - acc: 0.8892 - val_loss: 0.6509 - val_acc: 0.8231
#
# Epoch 00023: val_acc did not improve from 0.84180
# Epoch 24/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.3762 - acc: 0.8897 - val_loss: 0.5252 - val_acc: 0.8569
#
# Epoch 00024: val_acc improved from 0.84180 to 0.85690, saving model to assignment7b.h5
# Epoch 25/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.3632 - acc: 0.8969 - val_loss: 0.5631 - val_acc: 0.8435
#
# Epoch 00025: val_acc did not improve from 0.85690
# Epoch 26/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.3549 - acc: 0.9000 - val_loss: 0.5766 - val_acc: 0.8412
#
# Epoch 00026: val_acc did not improve from 0.85690
# Epoch 27/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.3522 - acc: 0.8991 - val_loss: 0.5957 - val_acc: 0.8391
#
# Epoch 00027: val_acc did not improve from 0.85690
# Epoch 28/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.3456 - acc: 0.9041 - val_loss: 1.1986 - val_acc: 0.7088
#
# Epoch 00028: val_acc did not improve from 0.85690
# Epoch 29/125
# 97/97 [==============================] - 90s 928ms/step - loss: 0.3370 - acc: 0.9053 - val_loss: 0.5255 - val_acc: 0.8580
#
# Epoch 00029: val_acc improved from 0.85690 to 0.85800, saving model to assignment7b.h5
# Epoch 30/125
# 97/97 [==============================] - 90s 928ms/step - loss: 0.3323 - acc: 0.9079 - val_loss: 0.5626 - val_acc: 0.8476
#
# Epoch 00030: val_acc did not improve from 0.85800
# Epoch 31/125
# 97/97 [==============================] - 90s 928ms/step - loss: 0.3290 - acc: 0.9095 - val_loss: 0.7136 - val_acc: 0.8192
#
# Epoch 00031: val_acc did not improve from 0.85800
# Epoch 32/125
# 97/97 [==============================] - 90s 928ms/step - loss: 0.2879 - acc: 0.9246 - val_loss: 0.4556 - val_acc: 0.8785
#
# Epoch 00032: val_acc improved from 0.85800 to 0.87850, saving model to assignment7b.h5
# Epoch 33/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.2638 - acc: 0.9318 - val_loss: 0.4584 - val_acc: 0.8768
#
# Epoch 00033: val_acc did not improve from 0.87850
# Epoch 34/125
# 97/97 [==============================] - 90s 928ms/step - loss: 0.2505 - acc: 0.9352 - val_loss: 0.5014 - val_acc: 0.8705
#
# Epoch 00034: val_acc did not improve from 0.87850
# Epoch 35/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.2516 - acc: 0.9356 - val_loss: 0.5223 - val_acc: 0.8681
#
# Epoch 00035: val_acc did not improve from 0.87850
# Epoch 36/125
# 97/97 [==============================] - 90s 928ms/step - loss: 0.2416 - acc: 0.9372 - val_loss: 0.5234 - val_acc: 0.8590
#
# Epoch 00036: val_acc did not improve from 0.87850
# Epoch 37/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.2427 - acc: 0.9375 - val_loss: 0.4984 - val_acc: 0.8711
#
# Epoch 00037: val_acc did not improve from 0.87850
# Epoch 38/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.2368 - acc: 0.9390 - val_loss: 0.5399 - val_acc: 0.8630
#
# Epoch 00038: val_acc did not improve from 0.87850
# Epoch 39/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.2282 - acc: 0.9424 - val_loss: 0.5356 - val_acc: 0.8622
#
# Epoch 00039: val_acc did not improve from 0.87850
# Epoch 40/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.2271 - acc: 0.9418 - val_loss: 0.4835 - val_acc: 0.8737
#
# Epoch 00040: val_acc did not improve from 0.87850
# Epoch 41/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.2207 - acc: 0.9438 - val_loss: 0.4400 - val_acc: 0.8847
#
# Epoch 00041: val_acc improved from 0.87850 to 0.88470, saving model to assignment7b.h5
# Epoch 42/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.2215 - acc: 0.9429 - val_loss: 0.6031 - val_acc: 0.8550
#
# Epoch 00042: val_acc did not improve from 0.88470
# Epoch 43/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.2242 - acc: 0.9425 - val_loss: 0.5064 - val_acc: 0.8686
#
# Epoch 00043: val_acc did not improve from 0.88470
# Epoch 44/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.2182 - acc: 0.9432 - val_loss: 0.5221 - val_acc: 0.8692
#
# Epoch 00044: val_acc did not improve from 0.88470
# Epoch 45/125
# 97/97 [==============================] - 90s 928ms/step - loss: 0.2163 - acc: 0.9460 - val_loss: 0.4941 - val_acc: 0.8712
#
# Epoch 00045: val_acc did not improve from 0.88470
# Epoch 46/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.2094 - acc: 0.9468 - val_loss: 0.4665 - val_acc: 0.8812
#
# Epoch 00046: val_acc did not improve from 0.88470
# Epoch 47/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.2033 - acc: 0.9496 - val_loss: 0.4586 - val_acc: 0.8802
#
# Epoch 00047: val_acc did not improve from 0.88470
# Epoch 48/125
# 97/97 [==============================] - 90s 925ms/step - loss: 0.2056 - acc: 0.9496 - val_loss: 0.5401 - val_acc: 0.8685
#
# Epoch 00048: val_acc did not improve from 0.88470
# Epoch 49/125
# 97/97 [==============================] - 90s 928ms/step - loss: 0.2050 - acc: 0.9490 - val_loss: 0.5475 - val_acc: 0.8681
#
# Epoch 00049: val_acc did not improve from 0.88470
# Epoch 50/125
# 97/97 [==============================] - 90s 928ms/step - loss: 0.2015 - acc: 0.9506 - val_loss: 0.4924 - val_acc: 0.8740
#
# Epoch 00050: val_acc did not improve from 0.88470
# Epoch 51/125
# 97/97 [==============================] - 90s 928ms/step - loss: 0.1984 - acc: 0.9503 - val_loss: 0.5092 - val_acc: 0.8782
#
# Epoch 00051: val_acc did not improve from 0.88470
# Epoch 52/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1814 - acc: 0.9565 - val_loss: 0.4773 - val_acc: 0.8835
#
# Epoch 00052: val_acc did not improve from 0.88470
# Epoch 53/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1678 - acc: 0.9613 - val_loss: 0.4388 - val_acc: 0.8899
#
# Epoch 00053: val_acc improved from 0.88470 to 0.88990, saving model to assignment7b.h5
# Epoch 54/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1665 - acc: 0.9613 - val_loss: 0.5001 - val_acc: 0.8779
#
# Epoch 00054: val_acc did not improve from 0.88990
# Epoch 55/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1647 - acc: 0.9616 - val_loss: 0.4405 - val_acc: 0.8916
#
# Epoch 00055: val_acc improved from 0.88990 to 0.89160, saving model to assignment7b.h5
# Epoch 56/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1610 - acc: 0.9626 - val_loss: 0.5400 - val_acc: 0.8689
#
# Epoch 00056: val_acc did not improve from 0.89160
# Epoch 57/125
# 97/97 [==============================] - 90s 928ms/step - loss: 0.1601 - acc: 0.9634 - val_loss: 0.4760 - val_acc: 0.8852
#
# Epoch 00057: val_acc did not improve from 0.89160
# Epoch 58/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1588 - acc: 0.9632 - val_loss: 0.5013 - val_acc: 0.8810
#
# Epoch 00058: val_acc did not improve from 0.89160
# Epoch 59/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1533 - acc: 0.9648 - val_loss: 0.5195 - val_acc: 0.8734
#
# Epoch 00059: val_acc did not improve from 0.89160
# Epoch 60/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1521 - acc: 0.9655 - val_loss: 0.4330 - val_acc: 0.8946
#
# Epoch 00060: val_acc improved from 0.89160 to 0.89460, saving model to assignment7b.h5
# Epoch 61/125
# 97/97 [==============================] - 90s 928ms/step - loss: 0.1502 - acc: 0.9660 - val_loss: 0.4314 - val_acc: 0.8937
#
# Epoch 00061: val_acc did not improve from 0.89460
# Epoch 62/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1403 - acc: 0.9690 - val_loss: 0.4168 - val_acc: 0.8991
#
# Epoch 00062: val_acc improved from 0.89460 to 0.89910, saving model to assignment7b.h5
# Epoch 63/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1308 - acc: 0.9721 - val_loss: 0.4213 - val_acc: 0.8986
#
# Epoch 00063: val_acc did not improve from 0.89910
# Epoch 64/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1297 - acc: 0.9742 - val_loss: 0.4486 - val_acc: 0.8933
#
# Epoch 00064: val_acc did not improve from 0.89910
# Epoch 65/125
# 97/97 [==============================] - 90s 928ms/step - loss: 0.1281 - acc: 0.9743 - val_loss: 0.4539 - val_acc: 0.8928
#
# Epoch 00065: val_acc did not improve from 0.89910
# Epoch 66/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1251 - acc: 0.9751 - val_loss: 0.4570 - val_acc: 0.8910
#
# Epoch 00066: val_acc did not improve from 0.89910
# Epoch 67/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1236 - acc: 0.9749 - val_loss: 0.4331 - val_acc: 0.9003
#
# Epoch 00067: val_acc improved from 0.89910 to 0.90030, saving model to assignment7b.h5
# Epoch 68/125
# 97/97 [==============================] - 90s 928ms/step - loss: 0.1203 - acc: 0.9758 - val_loss: 0.4290 - val_acc: 0.8994
#
# Epoch 00068: val_acc did not improve from 0.90030
# Epoch 69/125
# 97/97 [==============================] - 90s 929ms/step - loss: 0.1192 - acc: 0.9759 - val_loss: 0.4402 - val_acc: 0.8980
#
# Epoch 00069: val_acc did not improve from 0.90030
# Epoch 70/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1213 - acc: 0.9753 - val_loss: 0.4582 - val_acc: 0.8930
#
# Epoch 00070: val_acc did not improve from 0.90030
# Epoch 71/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1198 - acc: 0.9762 - val_loss: 0.4456 - val_acc: 0.8962
#
# Epoch 00071: val_acc did not improve from 0.90030
# Epoch 72/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1141 - acc: 0.9780 - val_loss: 0.4350 - val_acc: 0.8998
#
# Epoch 00072: val_acc did not improve from 0.90030
# Epoch 73/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1141 - acc: 0.9781 - val_loss: 0.4371 - val_acc: 0.8989
#
# Epoch 00073: val_acc did not improve from 0.90030
# Epoch 74/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1117 - acc: 0.9796 - val_loss: 0.4351 - val_acc: 0.9001
#
# Epoch 00074: val_acc did not improve from 0.90030
# Epoch 75/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1149 - acc: 0.9781 - val_loss: 0.4290 - val_acc: 0.9002
#
# Epoch 00075: val_acc did not improve from 0.90030
# Epoch 76/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1116 - acc: 0.9789 - val_loss: 0.4339 - val_acc: 0.8993
#
# Epoch 00076: val_acc did not improve from 0.90030
# Epoch 77/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1112 - acc: 0.9800 - val_loss: 0.4350 - val_acc: 0.8990
#
# Epoch 00077: val_acc did not improve from 0.90030
# Epoch 78/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1099 - acc: 0.9801 - val_loss: 0.4275 - val_acc: 0.9016
#
# Epoch 00078: val_acc improved from 0.90030 to 0.90160, saving model to assignment7b.h5
# Epoch 79/125
# 97/97 [==============================] - 90s 928ms/step - loss: 0.1110 - acc: 0.9791 - val_loss: 0.4303 - val_acc: 0.9008
#
# Epoch 00079: val_acc did not improve from 0.90160
# Epoch 80/125
# 97/97 [==============================] - 90s 928ms/step - loss: 0.1120 - acc: 0.9787 - val_loss: 0.4248 - val_acc: 0.9026
#
# Epoch 00080: val_acc improved from 0.90160 to 0.90260, saving model to assignment7b.h5
# Epoch 81/125
# 97/97 [==============================] - 90s 928ms/step - loss: 0.1093 - acc: 0.9801 - val_loss: 0.4279 - val_acc: 0.9019
#
# Epoch 00081: val_acc did not improve from 0.90260
# Epoch 82/125
# 97/97 [==============================] - 90s 928ms/step - loss: 0.1105 - acc: 0.9793 - val_loss: 0.4316 - val_acc: 0.9006
#
# Epoch 00082: val_acc did not improve from 0.90260
# Epoch 83/125
# 97/97 [==============================] - 90s 928ms/step - loss: 0.1110 - acc: 0.9797 - val_loss: 0.4288 - val_acc: 0.9024
#
# Epoch 00083: val_acc did not improve from 0.90260
# Epoch 84/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1083 - acc: 0.9803 - val_loss: 0.4283 - val_acc: 0.9005
#
# Epoch 00084: val_acc did not improve from 0.90260
# Epoch 85/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1086 - acc: 0.9801 - val_loss: 0.4286 - val_acc: 0.9013
#
# Epoch 00085: val_acc did not improve from 0.90260
# Epoch 86/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1099 - acc: 0.9797 - val_loss: 0.4300 - val_acc: 0.9010
#
# Epoch 00086: val_acc did not improve from 0.90260
# Epoch 87/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1090 - acc: 0.9791 - val_loss: 0.4324 - val_acc: 0.9010
#
# Epoch 00087: val_acc did not improve from 0.90260
# Epoch 88/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1103 - acc: 0.9794 - val_loss: 0.4327 - val_acc: 0.9009
#
# Epoch 00088: val_acc did not improve from 0.90260
# Epoch 89/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1067 - acc: 0.9804 - val_loss: 0.4298 - val_acc: 0.9011
#
# Epoch 00089: val_acc did not improve from 0.90260
# Epoch 90/125
# 97/97 [==============================] - 90s 925ms/step - loss: 0.1098 - acc: 0.9793 - val_loss: 0.4321 - val_acc: 0.9003
#
# Epoch 00090: val_acc did not improve from 0.90260
# Epoch 91/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1085 - acc: 0.9798 - val_loss: 0.4303 - val_acc: 0.9008
#
# Epoch 00091: val_acc did not improve from 0.90260
# Epoch 92/125
# 97/97 [==============================] - 90s 925ms/step - loss: 0.1095 - acc: 0.9796 - val_loss: 0.4294 - val_acc: 0.9015
#
# Epoch 00092: val_acc did not improve from 0.90260
# Epoch 93/125
# 97/97 [==============================] - 90s 925ms/step - loss: 0.1065 - acc: 0.9810 - val_loss: 0.4288 - val_acc: 0.9020
#
# Epoch 00093: val_acc did not improve from 0.90260
# Epoch 94/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1085 - acc: 0.9800 - val_loss: 0.4279 - val_acc: 0.9022
#
# Epoch 00094: val_acc did not improve from 0.90260
# Epoch 95/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1088 - acc: 0.9795 - val_loss: 0.4282 - val_acc: 0.9025
#
# Epoch 00095: val_acc did not improve from 0.90260
# Epoch 96/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1090 - acc: 0.9799 - val_loss: 0.4279 - val_acc: 0.9024
#
# Epoch 00096: val_acc did not improve from 0.90260
# Epoch 97/125
# 97/97 [==============================] - 90s 925ms/step - loss: 0.1093 - acc: 0.9795 - val_loss: 0.4281 - val_acc: 0.9020
#
# Epoch 00097: val_acc did not improve from 0.90260
# Epoch 98/125
# 97/97 [==============================] - 92s 948ms/step - loss: 0.1101 - acc: 0.9791 - val_loss: 0.4267 - val_acc: 0.9023
#
# Epoch 00098: val_acc did not improve from 0.90260
# Epoch 99/125
# 97/97 [==============================] - 90s 929ms/step - loss: 0.1086 - acc: 0.9799 - val_loss: 0.4280 - val_acc: 0.9026
#
# Epoch 00099: val_acc did not improve from 0.90260
# Epoch 100/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1070 - acc: 0.9801 - val_loss: 0.4275 - val_acc: 0.9025
#
# Epoch 00100: val_acc did not improve from 0.90260
# Epoch 101/125
# 97/97 [==============================] - 90s 925ms/step - loss: 0.1070 - acc: 0.9808 - val_loss: 0.4279 - val_acc: 0.9022
#
# Epoch 00101: val_acc did not improve from 0.90260
# Epoch 102/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1084 - acc: 0.9798 - val_loss: 0.4286 - val_acc: 0.9023
#
# Epoch 00102: val_acc did not improve from 0.90260
# Epoch 103/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1082 - acc: 0.9805 - val_loss: 0.4286 - val_acc: 0.9027
#
# Epoch 00103: val_acc improved from 0.90260 to 0.90270, saving model to assignment7b.h5
# Epoch 104/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1072 - acc: 0.9812 - val_loss: 0.4275 - val_acc: 0.9027
#
# Epoch 00104: val_acc did not improve from 0.90270
# Epoch 105/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1069 - acc: 0.9808 - val_loss: 0.4281 - val_acc: 0.9026
#
# Epoch 00105: val_acc did not improve from 0.90270
# Epoch 106/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1078 - acc: 0.9804 - val_loss: 0.4280 - val_acc: 0.9024
#
# Epoch 00106: val_acc did not improve from 0.90270
# Epoch 107/125
# 97/97 [==============================] - 90s 925ms/step - loss: 0.1072 - acc: 0.9800 - val_loss: 0.4279 - val_acc: 0.9025
#
# Epoch 00107: val_acc did not improve from 0.90270
# Epoch 108/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1081 - acc: 0.9807 - val_loss: 0.4275 - val_acc: 0.9024
#
# Epoch 00108: val_acc did not improve from 0.90270
# Epoch 109/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1076 - acc: 0.9805 - val_loss: 0.4281 - val_acc: 0.9024
#
# Epoch 00109: val_acc did not improve from 0.90270
# Epoch 110/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1068 - acc: 0.9806 - val_loss: 0.4276 - val_acc: 0.9026
#
# Epoch 00110: val_acc did not improve from 0.90270
# Epoch 111/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1077 - acc: 0.9802 - val_loss: 0.4280 - val_acc: 0.9023
#
# Epoch 00111: val_acc did not improve from 0.90270
# Epoch 112/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1090 - acc: 0.9799 - val_loss: 0.4286 - val_acc: 0.9024
#
# Epoch 00112: val_acc did not improve from 0.90270
# Epoch 113/125
# 97/97 [==============================] - 90s 925ms/step - loss: 0.1060 - acc: 0.9803 - val_loss: 0.4282 - val_acc: 0.9024
#
# Epoch 00113: val_acc did not improve from 0.90270
# Epoch 114/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1077 - acc: 0.9802 - val_loss: 0.4283 - val_acc: 0.9022
#
# Epoch 00114: val_acc did not improve from 0.90270
# Epoch 115/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1069 - acc: 0.9805 - val_loss: 0.4283 - val_acc: 0.9022
#
# Epoch 00115: val_acc did not improve from 0.90270
# Epoch 116/125
# 97/97 [==============================] - 90s 925ms/step - loss: 0.1059 - acc: 0.9811 - val_loss: 0.4285 - val_acc: 0.9023
#
# Epoch 00116: val_acc did not improve from 0.90270
# Epoch 117/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1074 - acc: 0.9805 - val_loss: 0.4284 - val_acc: 0.9023
#
# Epoch 00117: val_acc did not improve from 0.90270
# Epoch 118/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1061 - acc: 0.9805 - val_loss: 0.4275 - val_acc: 0.9027
#
# Epoch 00118: val_acc did not improve from 0.90270
# Epoch 119/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1072 - acc: 0.9804 - val_loss: 0.4273 - val_acc: 0.9027
#
# Epoch 00119: val_acc did not improve from 0.90270
# Epoch 120/125
# 97/97 [==============================] - 90s 928ms/step - loss: 0.1072 - acc: 0.9808 - val_loss: 0.4284 - val_acc: 0.9021
#
# Epoch 00120: val_acc did not improve from 0.90270
# Epoch 121/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1084 - acc: 0.9800 - val_loss: 0.4279 - val_acc: 0.9025
#
# Epoch 00121: val_acc did not improve from 0.90270
# Epoch 122/125
# 97/97 [==============================] - 90s 925ms/step - loss: 0.1092 - acc: 0.9799 - val_loss: 0.4277 - val_acc: 0.9022
#
# Epoch 00122: val_acc did not improve from 0.90270
# Epoch 123/125
# 97/97 [==============================] - 90s 926ms/step - loss: 0.1099 - acc: 0.9788 - val_loss: 0.4284 - val_acc: 0.9024
#
# Epoch 00123: val_acc did not improve from 0.90270
# Epoch 124/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1069 - acc: 0.9804 - val_loss: 0.4280 - val_acc: 0.9025
#
# Epoch 00124: val_acc did not improve from 0.90270
# Epoch 125/125
# 97/97 [==============================] - 90s 927ms/step - loss: 0.1065 - acc: 0.9802 - val_loss: 0.4270 - val_acc: 0.9027
#
# Epoch 00125: val_acc did not improve from 0.90270
# Model took 11281.96 seconds to train
# Accuracy on test data is: 90.27
